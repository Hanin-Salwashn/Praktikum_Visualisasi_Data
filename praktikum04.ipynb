# %% [markdown]
# <a href="https://colab.research.google.com/github/Hanin-Salwashn/Praktikum_Visualisasi_Data/blob/main/praktikum04.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **PRAKTIKUM BAR CHART**

# %% [markdown]
# **Kelompok 4**
# * Erina Nurul Hodijah - 0110112113
# * Hanin Salwa Salsabila Hidayati Nurrohman - 0110122294
# * Mohammad Ramdhani - 0110122083

# %%
import matplotlib.pyplot as plt

# data
jurusan = [
    'Ilmu Komputer',
    'Teknik Informatika',
    'Sistem Informasi',
    'Data Science'
]

jumlah_mahasiswa = [120, 150, 100, 80]

# membuat basic bar chart
plt.bar(jurusan, jumlah_mahasiswa, color=['blue', 'orange', 'pink', 'red'])
plt.xlabel('Jurusan')
plt.ylabel('Jumlah Mahasiswa')
plt.title('Jumlah Mahasiswa per Jurusan')
plt.show()

# %% [markdown]
# **a. Basic Bar Chart dengan Matplotlib**

# %%
import matplotlib.pyplot as plt

# data
jurusan = [
    'Ilmu Komputer',
    'Teknik Informatika',
    'Sistem Informasi',
    'Data Science'
]

jumlah_mahasiswa = [120, 150, 100, 80]

# membuat basic bar chart
plt.bar(jurusan, jumlah_mahasiswa, color=['blue', 'orange', 'pink', 'red'])
plt.xlabel('Jurusan')
plt.ylabel('Jumlah Mahasiswa')
plt.xticks(rotation=15)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.title('Jumlah Mahasiswa per Jurusan')
plt.show()

# %% [markdown]
# **b. Kustomisasi Basic Bar Chart**

# %%
import matplotlib.pyplot as plt

# data
jurusan = [
    'Ilmu Komputer',
    'Teknik Informatika',
    'Sistem Informasi',
    'Data Science'
]

jumlah_mahasiswa = [120, 150, 100, 80]

# membuat basic bar chart
plt.bar(jurusan, jumlah_mahasiswa, color=['blue', 'orange', 'pink', 'red'])
plt.xlabel('Jurusan')
plt.ylabel('Jumlah Mahasiswa')
plt.xticks(rotation=15)
plt.title('Jumlah Mahasiswa per Jurusan')

# menambahkan label pada batang
for i, v in enumerate(jumlah_mahasiswa):
    plt.text(i, v, str(v), ha='center', va='bottom')

plt.show()

# %% [markdown]
# **c. Multiple Bar Chart**

# %%
import matplotlib.pyplot as plt

# data
jurusan = [
    'Ilmu Komputer',
    'Teknik Informatika',
    'Sistem Informasi',
    'Data Science'
]

jumlah_mahasiswa = [120, 150, 100, 80]
jumlah_mahasiswa_2024 = [100, 140, 95, 85]

x = range(len(jurusan))
width = 0.4

plt.bar(x, jumlah_mahasiswa, width, label='2023', color='blue')
plt.bar([p + width for p in x], jumlah_mahasiswa_2024, width=width, label='2024', color='skyblue')

plt.title('Jumlah Mahasiswa per Jurusan 2023 vs 2024')
plt.xlabel('Jurusan')
plt.ylabel('Jumlah Mahasiswa')
plt.xticks(rotation=15)
plt.xticks([p + width/2 for p in x], jurusan)
plt.legend()

plt.show()

# %% [markdown]
# **d. Basic Bar Chart untuk Melihat Pola dan Tren**

# %%
import matplotlib.pyplot as plt

# data
jurusan = ['ilmu komputer', 'Teknik Informatika', 'Sistem Informasi', 'Data Science']
tahun = ['2019', '2020', '2021', '2022', '2023']
data = {
    'ilmu komputer': [100, 110, 120, 130, 140],
    'Teknik Informatika': [120, 120, 132, 145, 160],
    'Sistem Informasi': [90, 95, 100, 105, 110],
    'Data Science': [70, 75, 80, 85, 90]
}
width = 0.2
x = range(len(tahun))

# visualisasi masing" jurusan
plt.bar(x, data['ilmu komputer'], width=width, label='ilmu komputer', color='blue')
plt.bar([p + width for p in x],
        data['Teknik Informatika'], width=width, label='Teknik Informatika', color='orange')
plt.bar([p + width * 2 for p in x],
        data['Sistem Informasi'], width=width, label='Sistem Informasi', color='pink')
plt.bar([p + width * 3 for p in x],
        data['Data Science'], width=width, label='Data Science', color='red')

# detail grafik
plt.title('Tren Jumlah Mahasiswa per Jurusan (2019 vs 2023)')
plt.xlabel('tahun')
plt.ylabel('Jumlah Mahasiswa')
plt.xticks([p + width for p in x], tahun)
plt.legend()
plt.show()
