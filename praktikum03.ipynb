# %% [markdown]
# <a href="https://colab.research.google.com/github/Hanin-Salwashn/Praktikum_Visualisasi_Data/blob/main/praktikum03.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **PRAKTIKUM LINE CHART**

# %% [markdown]
# **Kelompok 4**
# * Erina Nurul Hodijah - 0110112113
# * Hanin Salwa Salsabila Hidayati Nurrohman - 0110122294
# * Mohammad Ramdhani - 0110122083

# %%
import matplotlib.pyplot as plt

# Data sample
months = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']
product_A_sales = [10, 20, 15, 25, 30, 45, 40, 50, 60, 55, 65, 70]
# product_B_sales = [5, 10, 8, 15, 18, 20, 22, 30, 25, 35, 40, 45] # Data ini tidak digunakan di sub-bab a

# Line Plot
plt.plot(months, product_A_sales)
plt.title('Penjualan Produk A Per Bulan')
plt.xlabel('Bulan')
plt.ylabel('Jumlah Penjualan')
plt.show()

# %% [markdown]
# **a. Line Plot dengan Matplotlib**

# %%
import matplotlib.pyplot as plt

# Data sample
months = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']
product_A_sales = [10, 20, 15, 25, 30, 45, 40, 50, 60, 55, 65, 70]
product_B_sales = [5, 10, 8, 15, 18, 20, 22, 30, 25, 35, 40, 45]

# Line Plot
plt.plot(months, product_A_sales)
plt.title('Penjualan Produk A Per Bulan')
plt.xlabel('Bulan')
plt.ylabel('Jumlah Penjualan')
plt.show()

# %% [markdown]
# **b. Kustomasi Line Plot**

# %%
import matplotlib.pyplot as plt

# Data sample
months = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']
product_A_sales = [10, 20, 15, 25, 30, 45, 40, 50, 60, 55, 65, 70]
product_B_sales = [5, 10, 8, 15, 18, 20, 22, 30, 25, 35, 40, 45]

# Line Plot dengan kustomisasi
plt.plot(months, product_A_sales, label='Product A', color='blue', linestyle='--', marker='o')
plt.plot(months, product_B_sales, label='Product B', color='red', linestyle='-', marker='x')

plt.title('Penjualan Produk Per Bulan')
plt.xlabel('Bulan')
plt.ylabel('Jumlah Penjualan')
plt.legend() # Menampilkan legend (keterangan)
plt.grid(True) # Menambahkan grid
plt.show()

# %% [markdown]
# **c. Menambahkan Multiple Lines**

# %%
import matplotlib.pyplot as plt

# Data sample
months = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']
product_A_sales = [10, 20, 15, 25, 30, 45, 40, 50, 60, 55, 65, 70]
product_B_sales = [5, 10, 8, 15, 18, 20, 22, 30, 25, 35, 40, 45]

# Line Plot dengan multiple lines dan marker
plt.plot(months, product_A_sales, label='Product A', marker="o")
plt.plot(months, product_B_sales, label='Product B', marker='x')

plt.title('Penjualan Produk Per Bulan')
plt.xlabel('Bulan')
plt.ylabel('Jumlah Penjualan')
plt.legend()
plt.show()

# %% [markdown]
# **d. Garis Berbeda untuk Menunjukkan Trend**

# %%
import matplotlib.pyplot as plt

# Data sample
months = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']
product_A_sales = [10, 20, 15, 25, 30, 45, 40, 50, 60, 55, 65, 70]
product_B_sales = [5, 10, 8, 15, 18, 20, 22, 30, 25, 35, 40, 45]

# Line Plot untuk menunjukkan trend
# LineStyle: '-' solid, '--' dashed, '-.' dashdot, ':' dotted
plt.plot(months, product_A_sales, label='Product A Trend', linestyle='--', color='blue')
plt.plot(months, product_B_sales, label='Product B Trend', linestyle=':', color='red')

plt.title('Tren Penjualan Produk Per Bulan')
plt.xlabel('Bulan')
plt.ylabel('Jumlah Penjualan')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# **e. Subplot untuk Menampilkan Beberapa Grafik**

# %%
import matplotlib.pyplot as plt

# Data sample
months = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']
product_A_sales = [10, 20, 15, 25, 30, 45, 40, 50, 60, 55, 65, 70]
product_B_sales = [5, 10, 8, 15, 18, 20, 22, 30, 25, 35, 40, 45]

# Line Plot dengan Subplot
fig, axs = plt.subplots(2, 1, figsize=(10, 8)) # Membuat 2 baris, 1 kolom subplot

# Plot untuk Product A (Subplot 0)
axs[0].plot(months, product_A_sales, label='Product A', color='blue', marker='o')
axs[0].set_title('Penjualan Produk A Per Bulan')
axs[0].set_xlabel('Bulan')
axs[0].set_ylabel('Jumlah Penjualan')
axs[0].legend()
axs[0].grid(True)

# Plot untuk Product B (Subplot 1)
axs[1].plot(months, product_B_sales, label='Product B', color='red', marker='x')
axs[1].set_title('Penjualan Produk B Per Bulan')
axs[1].set_xlabel('Bulan')
axs[1].set_ylabel('Jumlah Penjualan')
axs[1].legend()
axs[1].grid(True)

plt.tight_layout() # Merapikan tata letak antar subplot
plt.show()
